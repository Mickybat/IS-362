# %%
from pynytimes import NYTAPI
import pandas as pd 

nyt = NYTAPI("Xke0c1BKA01IW0mGTWmJ625GjJVrxQHX", parse_dates=True)

# %%
articles = nyt.article_search(query="inflation") 

df = pd.DataFrame(articles)
df.head(5)
# Out:
#                                             abstract  \
# 0  The rate of inflation in countries using the e...
# 1  When the Federal Reserve uses interest rate hi...
# 2  While fear of a “wage-price spiral” has eased,...
# 3  The president is framing slower employment gro...
# 4  A closely watched measure of price increases p...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/03/31/world/europ...
# 1  https://www.nytimes.com/2023/03/31/opinion/fed...
# 2  https://www.nytimes.com/2023/04/07/business/ec...
# 3  https://www.nytimes.com/2023/04/07/business/ec...
# 4  https://www.nytimes.com/2023/03/31/business/ec...
#
#                                              snippet  \
# 0  The rate of inflation in countries using the e...
# 1  When the Federal Reserve uses interest rate hi...
# 2  While fear of a “wage-price spiral” has eased,...
# 3  The president is framing slower employment gro...
# ...
